# %% [markdown]
# # Enhancing Gradient Descent

# %% [markdown]
# In this notebook we show how standardising data and the Adam optimiser can help gradient descent converge faster. We use Linear Regression instead of a Neural Network, so we can visualise the shape of the loss and the path Gradient Descent takes until the loss minimum.

# %%
import keras
from keras.models import Sequential
from tensorflow.keras import regularizers, initializers
from keras.layers import Dense
from keras import backend as K
from keras.callbacks import Callback
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.cm as cm
import tensorflow as tf
import numpy as np
from sklearn.utils import shuffle
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
import itertools
import os
# Out:
# 2025-06-21 16:32:24.317583: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-21 16:32:24.326957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750519944.337374  255858 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750519944.340638  255858 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-21 16:32:24.352995: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.sans-serif": ["Computer Modern Sans Serif"],
    "font.size": 14,
    "figure.dpi": 300})

# %% [markdown]
# ## Generating the data set

# %%
train_size = 1000

X_func = np.linspace(0, 10, 1001, endpoint=True)
y_func = 2 * X_func + 2

# %%
X_train = np.linspace(0, 10, train_size, endpoint=True)

## Uncomment to generate new random observations of training data
#y_train = (2 * X_train + 2 + np.random.normal(scale=2.0, size=train_size)).T
#np.savetxt('InputData/GradDesc-y_train.dat', y_train)

y_train = np.loadtxt('InputData/GradDesc-y_train.dat').reshape(-1,1)

# %%
plt.scatter(x=X_train, y=y_train, s=10, marker="o")
plt.plot(X_func, y_func, linewidth=3, linestyle='dashed', color='black')
plt.xlabel(r'$x$')
plt.ylabel(r'$y(x)$')
plt.legend(['Training Data', r'$2x + 2$'])
plt.savefig('Plots/GradDesc-data.png', bbox_inches='tight', pad_inches=0.01)
plt.show()

# %% [markdown]
# ## Callback to save weights during training

# %%
class WeightsHistory(tf.keras.callbacks.Callback):
    """
    A callback designed to save weights in a list after every single update.
    """
    def __init__(self):
        super().__init__()
        self.weights_history = []

    def on_train_batch_end(self, batch, logs=None):
        current_weights = [w.numpy().copy().item() for w in self.model.trainable_weights]
        self.weights_history.append(current_weights)

# %% [markdown]
# ## Some functions

# %%
def build_model(optimizer, start_w, start_b):
    """
    Builds a linear regression model with a custom starting point.

    Args:
        optimizer: Optimizer to train the model.
        start_w (float): Starting weight.
        start_b (float): Starting bias.

    Returns:
        model
    """
    model=Sequential()
    mse = tf.keras.losses.MeanSquaredError()
    model.add(Dense(1, activation='linear', input_dim=1, kernel_initializer=initializers.Constant([start_w]), bias_initializer=initializers.Constant([start_b])))
    model.compile(loss=mse, optimizer=optimizer, metrics=["mean_squared_error"])
    return model

# %%
# Specifically created for plotting.
def MSE(x, y_true, weights):
    """
    Computes the mean squared error (MSE).

    Args:
        x (float): Point of the domain.
        y_true (float): The true value of y associated with x.
        weights (float, float): Weight of x and bias terms.

    Returns:
        L (float): Value of MSE loss for point (x, y).
    """
    b, w = weights 
    y_pred = x * w + b 
    L = 0.5 * np.mean((y_true - y_pred)**2)
    return L

# %%
def plot_contour(f, b_bound, w_bound, resolution, fig, ax):
    """
    Comprises a few settings to draw the contour plots of the MSE loss function.

    Args:
        f: Loss function.
        b_bound (float, float): Range of the bias term b for plotting.
        w_bound (float, float): Range of the weight w for plotting.
        resolution (int): Number of points in a dimension of the meshgrid.
        fig: matplotlib Figure instance.
        ax: matplotlib Axes instance.

    Returns:
        fig: matplotlib Figure instance.
        ax: matplotlib Axes instance.
    """
    b_range = np.linspace(b_bound[0], b_bound[1], resolution)
    w_range = np.linspace(w_bound[0], w_bound[1], resolution)
    xg, yg = np.meshgrid(b_range, w_range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    print(zg.shape)
    cs = ax.contourf(xg, yg, zg, 20)
    fig.colorbar(cs)
    return fig, ax

# %% [markdown]
# ## Training and results

# %% [markdown]
# ### Batch gradient descent + Non-standardised data

# %%
opt = keras.optimizers.SGD(learning_rate=0.025)
model = build_model(opt, -10, -10)
model.summary()
# Out:
# I0000 00:00:1750519946.280311  255858 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9602 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/joao/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
weights_callback = WeightsHistory()
batch_size = 1000
epochs = 500 
hist=model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, callbacks=[weights_callback])
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750519946.523046  255949 service.cc:148] XLA service 0x74f530004820 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750519946.523069  255949 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# I0000 00:00:1750519946.535519  255949 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 6384.3223 - mean_squared_error: 6384.3223
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3189.4907 - mean_squared_error: 3189.4907
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1600.1201 - mean_squared_error: 1600.1201
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 809.2974 - mean_squared_error: 809.2974
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 415.6723 - mean_squared_error: 415.6723
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 219.6163 - mean_squared_error: 219.6163
# I0000 00:00:1750519946.604661  255949 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 219.6163 - mean_squared_error: 219.6163
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 121.8360 - mean_squared_error: 121.8360
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 72.9435 - mean_squared_error: 72.9435
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 48.3736 - mean_squared_error: 48.3736
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 35.9077 - mean_squared_error: 35.9077
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 29.4681 - mean_squared_error: 29.4681
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 26.0319 - mean_squared_error: 26.0319
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 24.0951 - mean_squared_error: 24.0951
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 22.9096 - mean_squared_error: 22.9096
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 22.1033 - mean_squared_error: 22.1033
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 21.4909 - mean_squared_error: 21.4909
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20.9800 - mean_squared_error: 20.9800
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20.5246 - mean_squared_error: 20.5246
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20.1018 - mean_squared_error: 20.1018
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19.6999 - mean_squared_error: 19.6999
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19.3130 - mean_squared_error: 19.3130
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.9383 - mean_squared_error: 18.9383
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.5740 - mean_squared_error: 18.5740
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.2191 - mean_squared_error: 18.2191
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.8733 - mean_squared_error: 17.8733
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.5360 - mean_squared_error: 17.5360
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.2070 - mean_squared_error: 17.2070
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16.8861 - mean_squared_error: 16.8861
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16.5730 - mean_squared_error: 16.5730
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16.2675 - mean_squared_error: 16.2675
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 15.9695 - mean_squared_error: 15.9695
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 15.6787 - mean_squared_error: 15.6787
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 15.3949 - mean_squared_error: 15.3949
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 15.1181 - mean_squared_error: 15.1181
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14.8481 - mean_squared_error: 14.8481
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14.5846 - mean_squared_error: 14.5846
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14.3275 - mean_squared_error: 14.3275
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 14.0766 - mean_squared_error: 14.0766
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 13.8319 - mean_squared_error: 13.8319
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.5931 - mean_squared_error: 13.5931
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.3602 - mean_squared_error: 13.3602
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.1329 - mean_squared_error: 13.1329
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12.9111 - mean_squared_error: 12.9111
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.6947 - mean_squared_error: 12.6947
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12.4836 - mean_squared_error: 12.4836
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12.2777 - mean_squared_error: 12.2777
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.0767 - mean_squared_error: 12.0767
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.8807 - mean_squared_error: 11.8807
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11.6894 - mean_squared_error: 11.6894
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 11.5027 - mean_squared_error: 11.5027
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11.3206 - mean_squared_error: 11.3206
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.1430 - mean_squared_error: 11.1430
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.9696 - mean_squared_error: 10.9696
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.8005 - mean_squared_error: 10.8005
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.6355 - mean_squared_error: 10.6355
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.4745 - mean_squared_error: 10.4745
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.3174 - mean_squared_error: 10.3174
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.1642 - mean_squared_error: 10.1642
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 10.0146 - mean_squared_error: 10.0146
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.8687 - mean_squared_error: 9.8687
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.7264 - mean_squared_error: 9.7264
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.5875 - mean_squared_error: 9.5875
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.4520 - mean_squared_error: 9.4520
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.3198 - mean_squared_error: 9.3198
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.1909 - mean_squared_error: 9.1909
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.0650 - mean_squared_error: 9.0650
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.9422 - mean_squared_error: 8.9422
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.8224 - mean_squared_error: 8.8224
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.7056 - mean_squared_error: 8.7056
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.5915 - mean_squared_error: 8.5915
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.4803 - mean_squared_error: 8.4803
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.3717 - mean_squared_error: 8.3717
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.2658 - mean_squared_error: 8.2658
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.1625 - mean_squared_error: 8.1625
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.0617 - mean_squared_error: 8.0617
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.9633 - mean_squared_error: 7.9633
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.8673 - mean_squared_error: 7.8673
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.7737 - mean_squared_error: 7.7737
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.6823 - mean_squared_error: 7.6823
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.5932 - mean_squared_error: 7.5932
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5062 - mean_squared_error: 7.5062
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.4214 - mean_squared_error: 7.4214
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.3386 - mean_squared_error: 7.3386
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.2578 - mean_squared_error: 7.2578
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.1790 - mean_squared_error: 7.1790
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.1021 - mean_squared_error: 7.1021
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.0271 - mean_squared_error: 7.0271
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.9539 - mean_squared_error: 6.9539
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.8825 - mean_squared_error: 6.8825
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.8128 - mean_squared_error: 6.8128
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.7449 - mean_squared_error: 6.7449
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6785 - mean_squared_error: 6.6785
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6138 - mean_squared_error: 6.6138
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5507 - mean_squared_error: 6.5507
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4891 - mean_squared_error: 6.4891
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4290 - mean_squared_error: 6.4290
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3704 - mean_squared_error: 6.3704
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.3131 - mean_squared_error: 6.3131
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.2573 - mean_squared_error: 6.2573
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.2029 - mean_squared_error: 6.2029
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.1497 - mean_squared_error: 6.1497
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.0979 - mean_squared_error: 6.0979
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.0473 - mean_squared_error: 6.0473
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9980 - mean_squared_error: 5.9980
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.9498 - mean_squared_error: 5.9498
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9028 - mean_squared_error: 5.9028
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.8570 - mean_squared_error: 5.8570
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.8123 - mean_squared_error: 5.8123
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7686 - mean_squared_error: 5.7686
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.7261 - mean_squared_error: 5.7261
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6845 - mean_squared_error: 5.6845
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6440 - mean_squared_error: 5.6440
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6045 - mean_squared_error: 5.6045
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5659 - mean_squared_error: 5.5659
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.5283 - mean_squared_error: 5.5283
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4916 - mean_squared_error: 5.4916
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4557 - mean_squared_error: 5.4557
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4208 - mean_squared_error: 5.4208
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.3867 - mean_squared_error: 5.3867
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.3534 - mean_squared_error: 5.3534
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.3209 - mean_squared_error: 5.3209
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.2893 - mean_squared_error: 5.2893
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2584 - mean_squared_error: 5.2584
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.2282 - mean_squared_error: 5.2282
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.1988 - mean_squared_error: 5.1988
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.1701 - mean_squared_error: 5.1701
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.1421 - mean_squared_error: 5.1421
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.1148 - mean_squared_error: 5.1148
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.0881 - mean_squared_error: 5.0881
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.0621 - mean_squared_error: 5.0621
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.0367 - mean_squared_error: 5.0367
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.0120 - mean_squared_error: 5.0120
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.9878 - mean_squared_error: 4.9878
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9642 - mean_squared_error: 4.9642
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.9412 - mean_squared_error: 4.9412
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.9188 - mean_squared_error: 4.9188
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.8969 - mean_squared_error: 4.8969
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.8756 - mean_squared_error: 4.8756
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.8547 - mean_squared_error: 4.8547
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.8344 - mean_squared_error: 4.8344
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8145 - mean_squared_error: 4.8145
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7952 - mean_squared_error: 4.7952
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7763 - mean_squared_error: 4.7763
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7579 - mean_squared_error: 4.7579
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7399 - mean_squared_error: 4.7399
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7224 - mean_squared_error: 4.7224
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7053 - mean_squared_error: 4.7053
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6886 - mean_squared_error: 4.6886
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6723 - mean_squared_error: 4.6723
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6564 - mean_squared_error: 4.6564
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.6409 - mean_squared_error: 4.6409
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6258 - mean_squared_error: 4.6258
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6110 - mean_squared_error: 4.6110
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.5966 - mean_squared_error: 4.5966
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5826 - mean_squared_error: 4.5826
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.5689 - mean_squared_error: 4.5689
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5555 - mean_squared_error: 4.5555
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5424 - mean_squared_error: 4.5424
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.5297 - mean_squared_error: 4.5297
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.5173 - mean_squared_error: 4.5173
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.5052 - mean_squared_error: 4.5052
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.4933 - mean_squared_error: 4.4933
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4818 - mean_squared_error: 4.4818
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4705 - mean_squared_error: 4.4705
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.4596 - mean_squared_error: 4.4596
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4488 - mean_squared_error: 4.4488
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.4384 - mean_squared_error: 4.4384
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4282 - mean_squared_error: 4.4282
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4182 - mean_squared_error: 4.4182
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4085 - mean_squared_error: 4.4085
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3991 - mean_squared_error: 4.3991
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3898 - mean_squared_error: 4.3898
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.3808 - mean_squared_error: 4.3808
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.3720 - mean_squared_error: 4.3720
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.3634 - mean_squared_error: 4.3634
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.3550 - mean_squared_error: 4.3550
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3469 - mean_squared_error: 4.3469
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3389 - mean_squared_error: 4.3389
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3311 - mean_squared_error: 4.3311
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3235 - mean_squared_error: 4.3235
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.3161 - mean_squared_error: 4.3161
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.3089 - mean_squared_error: 4.3089
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.3019 - mean_squared_error: 4.3019
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2950 - mean_squared_error: 4.2950
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2883 - mean_squared_error: 4.2883
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2817 - mean_squared_error: 4.2817
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2753 - mean_squared_error: 4.2753
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2691 - mean_squared_error: 4.2691
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2630 - mean_squared_error: 4.2630
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.2571 - mean_squared_error: 4.2571
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.2513 - mean_squared_error: 4.2513
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2457 - mean_squared_error: 4.2457
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.2401 - mean_squared_error: 4.2401
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2348 - mean_squared_error: 4.2348
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2295 - mean_squared_error: 4.2295
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2244 - mean_squared_error: 4.2244
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2194 - mean_squared_error: 4.2194
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2145 - mean_squared_error: 4.2145
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2098 - mean_squared_error: 4.2098
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2052 - mean_squared_error: 4.2052
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2006 - mean_squared_error: 4.2006
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1962 - mean_squared_error: 4.1962
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1919 - mean_squared_error: 4.1919
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1877 - mean_squared_error: 4.1877
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1836 - mean_squared_error: 4.1836
# Epoch 206/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1796 - mean_squared_error: 4.1796
# Epoch 207/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1757 - mean_squared_error: 4.1757
# Epoch 208/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1719 - mean_squared_error: 4.1719
# Epoch 209/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1682 - mean_squared_error: 4.1682
# Epoch 210/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1646 - mean_squared_error: 4.1646
# Epoch 211/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1610 - mean_squared_error: 4.1610
# Epoch 212/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1576 - mean_squared_error: 4.1576
# Epoch 213/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1542 - mean_squared_error: 4.1542
# Epoch 214/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1509 - mean_squared_error: 4.1509
# Epoch 215/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1477 - mean_squared_error: 4.1477
# Epoch 216/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1446 - mean_squared_error: 4.1446
# Epoch 217/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1415 - mean_squared_error: 4.1415
# Epoch 218/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1386 - mean_squared_error: 4.1386
# Epoch 219/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1357 - mean_squared_error: 4.1357
# Epoch 220/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1328 - mean_squared_error: 4.1328
# Epoch 221/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1301 - mean_squared_error: 4.1301
# Epoch 222/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1274 - mean_squared_error: 4.1274
# Epoch 223/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1247 - mean_squared_error: 4.1247
# Epoch 224/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1222 - mean_squared_error: 4.1222
# Epoch 225/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1197 - mean_squared_error: 4.1197
# Epoch 226/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1172 - mean_squared_error: 4.1172
# Epoch 227/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1148 - mean_squared_error: 4.1148
# Epoch 228/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1125 - mean_squared_error: 4.1125
# Epoch 229/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1102 - mean_squared_error: 4.1102
# Epoch 230/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1080 - mean_squared_error: 4.1080
# Epoch 231/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.1059 - mean_squared_error: 4.1059
# Epoch 232/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1038 - mean_squared_error: 4.1038
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1017 - mean_squared_error: 4.1017
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0997 - mean_squared_error: 4.0997
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0977 - mean_squared_error: 4.0977
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0958 - mean_squared_error: 4.0958
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0940 - mean_squared_error: 4.0940
# Epoch 238/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0921 - mean_squared_error: 4.0921
# Epoch 239/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0904 - mean_squared_error: 4.0904
# Epoch 240/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0886 - mean_squared_error: 4.0886
# Epoch 241/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0869 - mean_squared_error: 4.0869
# Epoch 242/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0853 - mean_squared_error: 4.0853
# Epoch 243/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0837 - mean_squared_error: 4.0837
# Epoch 244/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0821 - mean_squared_error: 4.0821
# Epoch 245/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0806 - mean_squared_error: 4.0806
# Epoch 246/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0791 - mean_squared_error: 4.0791
# Epoch 247/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0776 - mean_squared_error: 4.0776
# Epoch 248/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0762 - mean_squared_error: 4.0762
# Epoch 249/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0748 - mean_squared_error: 4.0748
# Epoch 250/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0735 - mean_squared_error: 4.0735
# Epoch 251/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0722 - mean_squared_error: 4.0722
# Epoch 252/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.0709 - mean_squared_error: 4.0709
# Epoch 253/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0696 - mean_squared_error: 4.0696
# Epoch 254/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0684 - mean_squared_error: 4.0684
# Epoch 255/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0672 - mean_squared_error: 4.0672
# Epoch 256/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0660 - mean_squared_error: 4.0660
# Epoch 257/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0649 - mean_squared_error: 4.0649
# Epoch 258/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0638 - mean_squared_error: 4.0638
# Epoch 259/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0627 - mean_squared_error: 4.0627
# Epoch 260/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0616 - mean_squared_error: 4.0616
# Epoch 261/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0606 - mean_squared_error: 4.0606
# Epoch 262/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0596 - mean_squared_error: 4.0596
# Epoch 263/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0586 - mean_squared_error: 4.0586
# Epoch 264/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0577 - mean_squared_error: 4.0577
# Epoch 265/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0567 - mean_squared_error: 4.0567
# Epoch 266/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0558 - mean_squared_error: 4.0558
# Epoch 267/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0549 - mean_squared_error: 4.0549
# Epoch 268/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0541 - mean_squared_error: 4.0541
# Epoch 269/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0532 - mean_squared_error: 4.0532
# Epoch 270/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0524 - mean_squared_error: 4.0524
# Epoch 271/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0516 - mean_squared_error: 4.0516
# Epoch 272/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0508 - mean_squared_error: 4.0508
# Epoch 273/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0500 - mean_squared_error: 4.0500
# Epoch 274/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0493 - mean_squared_error: 4.0493
# Epoch 275/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0485 - mean_squared_error: 4.0485
# Epoch 276/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0478 - mean_squared_error: 4.0478
# Epoch 277/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0471 - mean_squared_error: 4.0471
# Epoch 278/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0465 - mean_squared_error: 4.0465
# Epoch 279/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0458 - mean_squared_error: 4.0458
# Epoch 280/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0451 - mean_squared_error: 4.0451
# Epoch 281/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0445 - mean_squared_error: 4.0445
# Epoch 282/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0439 - mean_squared_error: 4.0439
# Epoch 283/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0433 - mean_squared_error: 4.0433
# Epoch 284/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0427 - mean_squared_error: 4.0427
# Epoch 285/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0421 - mean_squared_error: 4.0421
# Epoch 286/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0416 - mean_squared_error: 4.0416
# Epoch 287/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0410 - mean_squared_error: 4.0410
# Epoch 288/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0405 - mean_squared_error: 4.0405
# Epoch 289/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0400 - mean_squared_error: 4.0400
# Epoch 290/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0395 - mean_squared_error: 4.0395
# Epoch 291/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0390 - mean_squared_error: 4.0390
# Epoch 292/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0385 - mean_squared_error: 4.0385
# Epoch 293/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0380 - mean_squared_error: 4.0380
# Epoch 294/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0376 - mean_squared_error: 4.0376
# Epoch 295/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0371 - mean_squared_error: 4.0371
# Epoch 296/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0367 - mean_squared_error: 4.0367
# Epoch 297/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0363 - mean_squared_error: 4.0363
# Epoch 298/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0359 - mean_squared_error: 4.0359
# Epoch 299/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0355 - mean_squared_error: 4.0355
# Epoch 300/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0351 - mean_squared_error: 4.0351
# Epoch 301/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0347 - mean_squared_error: 4.0347
# Epoch 302/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0343 - mean_squared_error: 4.0343
# Epoch 303/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0339 - mean_squared_error: 4.0339
# Epoch 304/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0336 - mean_squared_error: 4.0336
# Epoch 305/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0332 - mean_squared_error: 4.0332
# Epoch 306/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0329 - mean_squared_error: 4.0329
# Epoch 307/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0326 - mean_squared_error: 4.0326
# Epoch 308/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0322 - mean_squared_error: 4.0322
# Epoch 309/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0319 - mean_squared_error: 4.0319
# Epoch 310/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0316 - mean_squared_error: 4.0316
# Epoch 311/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0313 - mean_squared_error: 4.0313
# Epoch 312/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0310 - mean_squared_error: 4.0310
# Epoch 313/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0307 - mean_squared_error: 4.0307
# Epoch 314/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0304 - mean_squared_error: 4.0304
# Epoch 315/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0302 - mean_squared_error: 4.0302
# Epoch 316/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0299 - mean_squared_error: 4.0299
# Epoch 317/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0296 - mean_squared_error: 4.0296
# Epoch 318/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0294 - mean_squared_error: 4.0294
# Epoch 319/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0291 - mean_squared_error: 4.0291
# Epoch 320/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0289 - mean_squared_error: 4.0289
# Epoch 321/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0287 - mean_squared_error: 4.0287
# Epoch 322/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0284 - mean_squared_error: 4.0284
# Epoch 323/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0282 - mean_squared_error: 4.0282
# Epoch 324/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0280 - mean_squared_error: 4.0280
# Epoch 325/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0278 - mean_squared_error: 4.0278
# Epoch 326/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0276 - mean_squared_error: 4.0276
# Epoch 327/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0274 - mean_squared_error: 4.0274
# Epoch 328/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0272 - mean_squared_error: 4.0272
# Epoch 329/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0270 - mean_squared_error: 4.0270
# Epoch 330/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0268 - mean_squared_error: 4.0268
# Epoch 331/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0266 - mean_squared_error: 4.0266
# Epoch 332/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0264 - mean_squared_error: 4.0264
# Epoch 333/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0263 - mean_squared_error: 4.0263
# Epoch 334/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0261 - mean_squared_error: 4.0261
# Epoch 335/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0259 - mean_squared_error: 4.0259
# Epoch 336/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0258 - mean_squared_error: 4.0258
# Epoch 337/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0256 - mean_squared_error: 4.0256
# Epoch 338/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0254 - mean_squared_error: 4.0254
# Epoch 339/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0253 - mean_squared_error: 4.0253
# Epoch 340/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0251 - mean_squared_error: 4.0251
# Epoch 341/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0250 - mean_squared_error: 4.0250
# Epoch 342/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0249 - mean_squared_error: 4.0249
# Epoch 343/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0247 - mean_squared_error: 4.0247
# Epoch 344/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0246 - mean_squared_error: 4.0246
# Epoch 345/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0245 - mean_squared_error: 4.0245
# Epoch 346/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0243 - mean_squared_error: 4.0243
# Epoch 347/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0242 - mean_squared_error: 4.0242
# Epoch 348/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0241 - mean_squared_error: 4.0241
# Epoch 349/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0240 - mean_squared_error: 4.0240
# Epoch 350/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0239 - mean_squared_error: 4.0239
# Epoch 351/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0237 - mean_squared_error: 4.0237
# Epoch 352/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0236 - mean_squared_error: 4.0236
# Epoch 353/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0235 - mean_squared_error: 4.0235
# Epoch 354/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0234 - mean_squared_error: 4.0234
# Epoch 355/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0233 - mean_squared_error: 4.0233
# Epoch 356/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0232 - mean_squared_error: 4.0232
# Epoch 357/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0231 - mean_squared_error: 4.0231
# Epoch 358/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0230 - mean_squared_error: 4.0230
# Epoch 359/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0229 - mean_squared_error: 4.0229
# Epoch 360/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0228 - mean_squared_error: 4.0228
# Epoch 361/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0228 - mean_squared_error: 4.0228
# Epoch 362/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0227 - mean_squared_error: 4.0227
# Epoch 363/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0226 - mean_squared_error: 4.0226
# Epoch 364/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0225 - mean_squared_error: 4.0225
# Epoch 365/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0224 - mean_squared_error: 4.0224
# Epoch 366/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0223 - mean_squared_error: 4.0223
# Epoch 367/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0223 - mean_squared_error: 4.0223
# Epoch 368/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0222 - mean_squared_error: 4.0222
# Epoch 369/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0221 - mean_squared_error: 4.0221
# Epoch 370/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0221 - mean_squared_error: 4.0221
# Epoch 371/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0220 - mean_squared_error: 4.0220
# Epoch 372/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0219 - mean_squared_error: 4.0219
# Epoch 373/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0219 - mean_squared_error: 4.0219
# Epoch 374/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0218 - mean_squared_error: 4.0218
# Epoch 375/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0217 - mean_squared_error: 4.0217
# Epoch 376/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0217 - mean_squared_error: 4.0217
# Epoch 377/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0216 - mean_squared_error: 4.0216
# Epoch 378/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.0216 - mean_squared_error: 4.0216
# Epoch 379/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0215 - mean_squared_error: 4.0215
# Epoch 380/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0214 - mean_squared_error: 4.0214
# Epoch 381/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0214 - mean_squared_error: 4.0214
# Epoch 382/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0213 - mean_squared_error: 4.0213
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0213 - mean_squared_error: 4.0213
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.0212 - mean_squared_error: 4.0212
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0212 - mean_squared_error: 4.0212
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0211 - mean_squared_error: 4.0211
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0211 - mean_squared_error: 4.0211
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0210 - mean_squared_error: 4.0210
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0210 - mean_squared_error: 4.0210
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0210 - mean_squared_error: 4.0210
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0209 - mean_squared_error: 4.0209
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0209 - mean_squared_error: 4.0209
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0208 - mean_squared_error: 4.0208
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0208 - mean_squared_error: 4.0208
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0208 - mean_squared_error: 4.0208
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0207 - mean_squared_error: 4.0207
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0207 - mean_squared_error: 4.0207
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0206 - mean_squared_error: 4.0206
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0206 - mean_squared_error: 4.0206
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0206 - mean_squared_error: 4.0206
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0205 - mean_squared_error: 4.0205
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0205 - mean_squared_error: 4.0205
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0205 - mean_squared_error: 4.0205
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0205 - mean_squared_error: 4.0205
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0204 - mean_squared_error: 4.0204
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0204 - mean_squared_error: 4.0204
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0204 - mean_squared_error: 4.0204
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0203 - mean_squared_error: 4.0203
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0203 - mean_squared_error: 4.0203
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0203 - mean_squared_error: 4.0203
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0203 - mean_squared_error: 4.0203
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0202 - mean_squared_error: 4.0202
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0202 - mean_squared_error: 4.0202
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0202 - mean_squared_error: 4.0202
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0202 - mean_squared_error: 4.0202
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0201 - mean_squared_error: 4.0201
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0201 - mean_squared_error: 4.0201
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0201 - mean_squared_error: 4.0201
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0201 - mean_squared_error: 4.0201
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0201 - mean_squared_error: 4.0201
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0200 - mean_squared_error: 4.0200
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0200 - mean_squared_error: 4.0200
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0200 - mean_squared_error: 4.0200
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0200 - mean_squared_error: 4.0200
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0200 - mean_squared_error: 4.0200
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0199 - mean_squared_error: 4.0199
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0198 - mean_squared_error: 4.0198
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0197 - mean_squared_error: 4.0197
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0196 - mean_squared_error: 4.0196
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0194 - mean_squared_error: 4.0194
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0193 - mean_squared_error: 4.0193

# %%
weights = np.asarray(weights_callback.weights_history)
weights = np.vstack([[-10, -10], weights]) #Starting point for the weight and bias
print(weights[-1]) #Confirming that gradient descent ended approximately at w=b=2.
# Out:
# [1.99112177 2.01364732]

# %%
cost_w = lambda param: MSE(X_train, y_train, param) #Define the cost just as a function of parameters (w and b).
fig, axes = plt.subplots()
plot_contour(cost_w, [-12,5], [-15,15], 200, fig, axes)
axes.set_xlabel(r'$b$')
axes.set_ylabel(r'$w$')
plt.plot(weights[:,1], weights[:,0], color='r', markersize=5)
plt.scatter([-10], [-10], s=20, color='red')
plt.savefig('Plots/GradDesc-BGD_NoSt.png', bbox_inches='tight', pad_inches=0.01)
plt.show()
# Out:
# (200, 200)

# %% [markdown]
# ### Batch gradient descent + Standardised data

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train.reshape(-1,1))
print(scaler.mean_, np.sqrt(scaler.var_))
# Out:
# [5.] [2.88963954]

# %%
#Solve in order to w and b the equation y = w * (x - mean) / std + b for two values of x and y = 2x + 2. For example, we used the points (0,2) and (10,22).
new_w = (2.0 * np.sqrt(scaler.var_)).item()
new_b = (2.0 + 2.0 * scaler.mean_).item()
print(new_w, new_b)
# Out:
# 5.779279084228419 11.999999999999998

# %%
opt = keras.optimizers.SGD(learning_rate=0.25)
model = build_model(opt, new_w - 12, new_b - 12) #We change the starting point, so gradient descent starts at the same distance as in the non-standardised case.
model.summary()
# Out:
# /home/joao/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
weights_callback = WeightsHistory()
batch_size = 1000
epochs = 12 
hist=model.fit(X_train_std, y_train, batch_size=batch_size, epochs=epochs, verbose=1, callbacks=[weights_callback])
# Out:
# Epoch 1/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 290.5703 - mean_squared_error: 290.5703
# Epoch 2/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 75.6570 - mean_squared_error: 75.6570
# Epoch 3/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 21.9287 - mean_squared_error: 21.9287
# Epoch 4/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.4966 - mean_squared_error: 8.4966
# Epoch 5/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1386 - mean_squared_error: 5.1386
# Epoch 6/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2991 - mean_squared_error: 4.2991
# Epoch 7/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0892 - mean_squared_error: 4.0892
# Epoch 8/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0367 - mean_squared_error: 4.0367
# Epoch 9/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0236 - mean_squared_error: 4.0236
# Epoch 10/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0203 - mean_squared_error: 4.0203
# Epoch 11/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0195 - mean_squared_error: 4.0195
# Epoch 12/12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0193 - mean_squared_error: 4.0193

# %%
weights = np.asarray(weights_callback.weights_history)
weights = np.vstack([[new_w - 12, new_b - 12], weights])
print(weights[-1]) #Confirming that gradient descent ended approximately at new_w and new_b.
# Out:
# [ 5.74147463 11.97150993]

# %%
cost_w = lambda param: MSE(X_train_std, y_train, param) #Define the cost just as a function of parameters (w and b).
fig, axes = plt.subplots()
plot_contour(cost_w, [-2,15], [-8,7], 200, fig, axes)
axes.set_xlabel(r'$b$')
axes.set_ylabel(r'$w$')
plt.plot(weights[:,1], weights[:,0], color='r', markersize=5)
plt.scatter([weights[:,1]], [weights[:,0]], s=20, color='red')
plt.savefig('Plots/GradDesc-BGD_St.png', bbox_inches='tight', pad_inches=0.01)
plt.show()
# Out:
# (200, 200)

# %% [markdown]
# ### Stochastic gradient descent + Standardised data

# %%
opt = keras.optimizers.SGD(learning_rate=0.005)
model = build_model(opt, new_w - 12, new_b - 12) #We change the starting point, so gradient descent starts at the same distance as in the non-standardised case.
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
weights_callback = WeightsHistory()
batch_size = 1
epochs = 2 
hist=model.fit(X_train_std, y_train, batch_size=batch_size, epochs=epochs, verbose=1, callbacks=[weights_callback])
# Out:
# Epoch 1/2
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 670us/step - loss: 51.0147 - mean_squared_error: 51.0147
# Epoch 2/2
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step - loss: 4.1776 - mean_squared_error: 4.1776

# %%
weights = np.asarray(weights_callback.weights_history)
weights = np.vstack([[new_w - 12, new_b - 12], weights])
print(weights[-1]) #Confirming that gradient descent ended approximately at new_w and new_b.
# Out:
# [ 5.71897221 11.95394707]

# %%
cost_w = lambda param: MSE(X_train_std, y_train, param) #Define the cost just as a function of parameters (w and b).
fig, axes = plt.subplots()
plot_contour(cost_w, [-2,15], [-8,7], 200, fig, axes)
axes.set_xlabel(r'$b$')
axes.set_ylabel(r'$w$')
plt.plot(weights[:,1], weights[:,0], color='r', markersize=5)
plt.scatter([new_b - 12], [new_w - 12], s=20, color='red')
plt.savefig('Plots/GradDesc-SGD_St.png', bbox_inches='tight', pad_inches=0.01)
plt.show()
# Out:
# (200, 200)

# %% [markdown]
# ### Adam + Standardised data

# %%
opt = keras.optimizers.Adam(learning_rate=0.25)
model = build_model(opt, new_w - 12, new_b - 12) #We change the starting point, so gradient descent starts at the same distance as in the non-standardised case.
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
weights_callback = WeightsHistory()
batch_size = 10
epochs = 2 
hist=model.fit(X_train_std, y_train, batch_size=batch_size, epochs=epochs, verbose=1, callbacks=[weights_callback])
# Out:
# Epoch 1/2
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 149.5096 - mean_squared_error: 149.5096
# Epoch 2/2
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6876 - mean_squared_error: 5.6876
# 2025-06-21 16:33:06.122160: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 4.0182 - mean_squared_error: 4.0182

# %%
weights = np.asarray(weights_callback.weights_history)
weights = np.vstack([[new_w - 12, new_b - 12], weights])
print(weights[-1]) #Confirming that gradient descent ended approximately at new_w and new_b.
# Out:
# [ 5.6878376  12.02130508]

# %%
cost_w = lambda param: MSE(X_train_std, y_train, param) #Define the cost just as a function of parameters (w and b).
fig, axes = plt.subplots()
plot_contour(cost_w, [-2,15], [-8,7], 200, fig, axes)
axes.set_xlabel(r'$b$')
axes.set_ylabel(r'$w$')
plt.plot(weights[:,1], weights[:,0], color='r', markersize=5)
plt.scatter([new_b - 12], [new_w - 12], s=20, color='red')
plt.savefig('Plots/GradDesc-Adam_St.png', bbox_inches='tight', pad_inches=0.01)
plt.show()
# Out:
# (200, 200)
